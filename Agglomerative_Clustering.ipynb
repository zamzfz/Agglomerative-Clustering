# %% [markdown]
# <a href="https://colab.research.google.com/github/zamzfz/Agglomerative-Clustering/blob/master/Agglomerative_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# %%
df = pd.read_csv('flame.csv')
df.columns = ['x','y',2]
df.head()
# Out:
#       x      y  2
# 0  1.35  26.65  1
# 1  1.40  23.25  2
# 2  0.85  23.05  2
# 3  0.50  22.35  2
# 4  0.65  21.35  2

# %%
endrogram = sch.dendrogram(sch.linkage(data,method='ward'))

# %%
plt.scatter(df['x'],df['y'])

# %%
hc = AgglomerativeClustering(n_clusters = 2, affinity='euclidean', linkage='ward')

# %%
y_hc = hc.fit_predict(df)

# %%
# plt.scatter(df['x'],df['y'], c=hc.labels_, cmap='rainbow')
plt.scatter(df[y_hc == 0]['x'], df[y_hc == 0]['y'], s = 100, c = 'green')
plt.scatter(df[y_hc == 1]['x'], df[y_hc == 1]['y'], s = 100, c = 'red')
